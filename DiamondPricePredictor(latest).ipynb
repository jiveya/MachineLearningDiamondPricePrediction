# %%
#Load the necessary library
import pandas as pd
import numpy as np
import seaborn as sb

# %%
#Load Dataset
df = pd.read_csv('diamond.csv')

# %%
#Exploratory Analysis- load dataset & check featues
df.shape
# Out:
# (53943, 11)

# %%
df.columns
# Out:
# Index(['SrNo.', 'carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price',
#        'x', 'y', 'z'],
#       dtype='object')

# %%
#Drop the unnecessary features-count
df.drop('SrNo.', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['carat', 'cut', 'color', 'clarity', 'depth', 'table', 'price', 'x', 'y',
#        'z'],
#       dtype='object')

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53943 entries, 0 to 53942
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53943 non-null  float64
#  1   cut      53943 non-null  object
#  2   color    53943 non-null  object
#  3   clarity  53943 non-null  object
#  4   depth    53943 non-null  float64
#  5   table    53943 non-null  float64
#  6   price    53943 non-null  int64
#  7   x        53943 non-null  float64
#  8   y        53943 non-null  float64
#  9   z        53943 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
df.isna().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
#Summary statistics of numeric variables
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53943.000000  53943.000000  53943.000000  53943.000000  53943.000000
# mean       0.797935     61.749322     57.457251   3932.734294      5.731158
# std        0.473999      1.432626      2.234549   3989.338447      1.121730
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53943.000000  53943.000000
# mean       5.734526      3.538730
# std        1.142103      0.705679
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
#Data Analysis & Visualization
corr_matrix = df.corr()
corr_matrix["price"].sort_values(ascending=False)
# Out:
# C:\Users\ACER NITRO\AppData\Local\Temp\ipykernel_4792\3784200235.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = df.corr()
# price    1.000000
# carat    0.921591
# x        0.884433
# y        0.865419
# z        0.861249
# table    0.127118
# depth   -0.010630
# Name: price, dtype: float64

# %%
df.query("x==0 or y==0 or z==0")
# Out:
#        carat        cut color clarity  depth  table  price     x     y    z
# 2207    1.00    Premium     G     SI2   59.1   59.0   3142  6.55  6.48  0.0
# 2314    1.01    Premium     H      I1   58.1   59.0   3167  6.66  6.60  0.0
# 4791    1.10    Premium     G     SI2   63.0   59.0   3696  6.50  6.47  0.0
# 5471    1.01    Premium     F     SI2   59.2   58.0   3837  6.50  6.47  0.0
# 10167   1.50       Good     G      I1   64.0   61.0   4731  7.15  7.04  0.0
# 11182   1.07      Ideal     F     SI2   61.6   56.0   4954  0.00  6.62  0.0
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.00  0.00  0.0
# 13601   1.15      Ideal     G     VS2   59.2   56.0   5564  6.88  6.83  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.00  0.00  0.0
# 24394   2.18    Premium     H     SI2   59.4   61.0  12631  8.49  8.45  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.00  0.00  0.0
# ...

# %%
sb.scatterplot(x=df.carat , y=df.price)
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
len(df.query("carat>3"))
# Out:
# 32

# %%
len(df.query("carat>2"))
# Out:
# 1889

# %%
sb.distplot(df.price)
# Out:
# C:\Users\ACER NITRO\AppData\Local\Temp\ipykernel_4792\1154681151.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(df.price)
# <Axes: xlabel='price', ylabel='Density'>

# %%
sb.pairplot(df)

# %%
#Data Preparation
df.query("z>10 or y>10")
# Out:
#        carat        cut color clarity  depth  table  price      x      y  \
# 24067   2.00    Premium     H     SI2   58.9   57.0  12210   8.09  58.90
# 25998   4.01    Premium     I      I1   61.0   61.0  15223  10.14  10.10
# 27415   5.01       Fair     J      I1   65.5   59.0  18018  10.74  10.54
# 27630   4.50       Fair     J      I1   65.8   58.0  18531  10.23  10.16
# 48410   0.51  Very Good     E     VS1   61.8   54.7   1970   5.12   5.15
# 49189   0.51      Ideal     E     VS1   61.8   55.0   2075   5.15  31.80
#
#            z
# 24067   8.06
# 25998   6.17
# 27415   6.98
# 27630   6.72
# 48410  31.80
# 49189   5.12

# %%
df.query("z>10 or y>10").index
# Out:
# Int64Index([24067, 25998, 27415, 27630, 48410, 49189], dtype='int64')

# %%
#Removing Outliers
df.drop(df.query("z>10 or y>10").index, inplace=True)
df.query("x==0 or y==0 or z==0")
# Out:
#        carat        cut color clarity  depth  table  price     x     y    z
# 2207    1.00    Premium     G     SI2   59.1   59.0   3142  6.55  6.48  0.0
# 2314    1.01    Premium     H      I1   58.1   59.0   3167  6.66  6.60  0.0
# 4791    1.10    Premium     G     SI2   63.0   59.0   3696  6.50  6.47  0.0
# 5471    1.01    Premium     F     SI2   59.2   58.0   3837  6.50  6.47  0.0
# 10167   1.50       Good     G      I1   64.0   61.0   4731  7.15  7.04  0.0
# 11182   1.07      Ideal     F     SI2   61.6   56.0   4954  0.00  6.62  0.0
# 11963   1.00  Very Good     H     VS2   63.3   53.0   5139  0.00  0.00  0.0
# 13601   1.15      Ideal     G     VS2   59.2   56.0   5564  6.88  6.83  0.0
# 15951   1.14       Fair     G     VS1   57.5   67.0   6381  0.00  0.00  0.0
# 24394   2.18    Premium     H     SI2   59.4   61.0  12631  8.49  8.45  0.0
# 24520   1.56      Ideal     G     VS2   62.2   54.0  12800  0.00  0.00  0.0
# ...

# %%
df.query("x==0 or y==0 or z==0").index
# Out:
# Int64Index([ 2207,  2314,  4791,  5471, 10167, 11182, 11963, 13601, 15951,
#             24394, 24520, 26123, 26243, 27112, 27429, 27503, 27739, 49556,
#             49557, 51506],
#            dtype='int64')

# %%
df.drop(df.query("x==0 or y==0 or z==0").index, inplace=True)
sb.pairplot(df)

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
#Feature Engineering
df['vol'] = df.x * df.y * df.z
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#          vol
# 0  38.202030
# 1  34.505856
# 2  38.076885
# 3  46.724580
# 4  51.917250

# %%
df.drop(['x','y','z'], axis=1, inplace=True)
df.head()
# Out:
#    carat      cut color clarity  depth  table  price        vol
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  38.202030
# 1   0.21  Premium     E     SI1   59.8   61.0    326  34.505856
# 2   0.23     Good     E     VS1   56.9   65.0    327  38.076885
# 3   0.29  Premium     I     VS2   62.4   58.0    334  46.724580
# 4   0.31     Good     J     SI2   63.3   58.0    335  51.917250

# %%
df.cut.unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
df.cut.replace({'Ideal':5, 'Premium':4, 'Good':2, 'Very Good':3, 'Fair':1}, inplace=True)
df.head()
# Out:
#    carat  cut color clarity  depth  table  price        vol
# 0   0.23    5     E     SI2   61.5   55.0    326  38.202030
# 1   0.21    4     E     SI1   59.8   61.0    326  34.505856
# 2   0.23    2     E     VS1   56.9   65.0    327  38.076885
# 3   0.29    4     I     VS2   62.4   58.0    334  46.724580
# 4   0.31    2     J     SI2   63.3   58.0    335  51.917250

# %%
df.color.unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
df.color.replace({'D':1,'E':2,'F':3,'G':4,'H':5, 'I':6, 'J':7,}, inplace=True)
df.head()
# Out:
#    carat  cut  color clarity  depth  table  price        vol
# 0   0.23    5      2     SI2   61.5   55.0    326  38.202030
# 1   0.21    4      2     SI1   59.8   61.0    326  34.505856
# 2   0.23    2      2     VS1   56.9   65.0    327  38.076885
# 3   0.29    4      6     VS2   62.4   58.0    334  46.724580
# 4   0.31    2      7     SI2   63.3   58.0    335  51.917250

# %%
df.clarity.unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
df.clarity.replace({'SI2':1, 'SI1':2, 'VS1':3, 'VS2':4, 'VVS2':5, 'VVS1':6, 'I1':7, 'IF':8}, inplace=True)
df.head()
# Out:
#    carat  cut  color  clarity  depth  table  price        vol
# 0   0.23    5      2        1   61.5   55.0    326  38.202030
# 1   0.21    4      2        2   59.8   61.0    326  34.505856
# 2   0.23    2      2        3   56.9   65.0    327  38.076885
# 3   0.29    4      6        4   62.4   58.0    334  46.724580
# 4   0.31    2      7        1   63.3   58.0    335  51.917250

# %%
X = df.drop(['price','table','depth','vol'], axis=1)
X.head()
# Out:
#    carat  cut  color  clarity
# 0   0.23    5      2        1
# 1   0.21    4      2        2
# 2   0.23    2      2        3
# 3   0.29    4      6        4
# 4   0.31    2      7        1

# %%
y = df['price']
y.head()
# Out:
# 0    326
# 1    326
# 2    327
# 3    334
# 4    335
# Name: price, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
#Modelling
import sklearn.linear_model as sl
linreg = sl.LinearRegression()
linreg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('R squared of the Linear Regression on training set: {:.2%}'.format(linreg.score(X_train, y_train)))
print('R squared of the Linear Regression on test set: {:.2%}'.format(linreg.score(X_test, y_test)))
# Out:
# R squared of the Linear Regression on training set: 88.25%
# R squared of the Linear Regression on test set: 88.26%

# %%
y_pred = linreg.predict(X_test)
sb.scatterplot(x=y_test , y=y_pred, color="blue")
# Out:
# <Axes: xlabel='price'>

# %%
import sklearn.tree as st
tree = st.DecisionTreeRegressor(random_state=42)
tree.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
print('R squared of the Decision Tree Regressor on training set: {:.2%}'.format(tree.score(X_train, y_train)))
print('R squared of the Decision Tree Regressor on test set: {:.2%}'.format(tree.score(X_test, y_test)))
# Out:
# R squared of the Decision Tree Regressor on training set: 99.23%
# R squared of the Decision Tree Regressor on test set: 97.29%

# %%
y_pred1 = tree.predict(X_test)
sb.scatterplot(x=y_test , y=y_pred1, color="red")
# Out:
# <Axes: xlabel='price'>

# %%
import sklearn.ensemble as se
rf = se.RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
print('R squared of the Random Forest Regressor on training set: {:.2%}'.format(rf.score(X_train, y_train)))
print('R squared of the Random Forest Regressor on test set: {:.2%}'.format(rf.score(X_test, y_test)))
# Out:
# R squared of the Random Forest Regressor on training set: 99.10%
# R squared of the Random Forest Regressor on test set: 97.87%

# %%
y_pred2 = rf.predict(X_test)
sb.scatterplot(x=y_test , y=y_pred2, color="green")
# Out:
# <Axes: xlabel='price'>

# %%
#Evaluating Linear Regression Model
d = {'true': y_test, 'predicted': y_pred}
df_lr = pd.DataFrame(data=d)
df_lr['diff'] = df_lr['predicted']-df_lr['true']
df_lr
# Out:
#        true    predicted         diff
# 33881   844   653.546241  -190.453759
# 21091  9261  7105.029046 -2155.970954
# 36464   942  1023.111854    81.111854
# 40260   492  -503.739362  -995.739362
# 1632   3016  3723.365497   707.365497
# ...     ...          ...          ...
# 37688   993  1417.290180   424.290180
# 53373  2659  3005.531602   346.531602
# 47479  1861  2618.160986   757.160986
# 13818  5630  6299.504051   669.504051
# 10163  4729  5422.986070   693.986070
#
# [17793 rows x 3 columns]

# %%
sb.displot(y_pred - y_test, color="blue")

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_log_error
print('Linear regression accuracy: ')
#crossl = cross_val_score(estimator = model, X = x_train, y = y_train, cv = 4,verbose = 0)
msel = mean_squared_error(y_test, y_pred)
rmsel = mean_squared_error(y_test, y_pred)**0.5
mael = mean_absolute_error(y_test, y_pred)
#msle =mean_squared_log_error(y_test,y_pred)
#print('Cross val     : ',crossl)
print('MAE           : ', mael)
print('MSE (RMSE)    : ', msel,' (',rmsel,')')
#print("MSLE  :", msle)
# Out:
# Linear regression accuracy:
# MAE           :  875.4468783725371
# MSE (RMSE)    :  1824231.0614910347  ( 1350.6409817161016 )

# %%
import matplotlib.pyplot as plt
plt.hist(y_pred[y_pred < 0 ])
# Out:
# (array([  2.,   3.,  27.,  34.,  65., 149., 190., 293., 408., 516.]),
#  array([-2.27958389e+03, -2.05163574e+03, -1.82368759e+03, -1.59573944e+03,
#         -1.36779129e+03, -1.13984314e+03, -9.11894984e+02, -6.83946832e+02,
#         -4.55998681e+02, -2.28050529e+02, -1.02377809e-01]),
#  <BarContainer object of 10 artists>)

# %%
#Evaluating Decision tree Regressor
d = {'true': y_test, 'predicted': y_pred1}
df_dt = pd.DataFrame(data=d)
df_dt['diff'] = df_dt['predicted']-df_dt['true']
mt=df_dt

# %%
print('Decision Tree regression accuracy: ')
#crossl = cross_val_score(estimator = model, X = x_train, y = y_train, cv = 4,verbose = 0)
msel = mean_squared_error(y_test, y_pred1)
rmsel = mean_squared_error(y_test, y_pred1)**0.5
mael = mean_absolute_error(y_test, y_pred1)
msle =mean_squared_log_error(y_test,y_pred1)
#print('Cross val     : ',crossl)
print('MAE           : ', mael)
print('MSE (RMSE)    : ', msel,' (',rmsel,')')
print("MSLE  :", msle)
# Out:
# Decision Tree regression accuracy:
# MAE           :  319.0097143517906
# MSE (RMSE)    :  421085.61312613264  ( 648.9110980143063 )
# MSLE  : 0.013950800371209906

# %%
d = {'true': y_test, 'predicted': y_pred2}
df_rf = pd.DataFrame(data=d)
df_rf['diff'] = df_rf['predicted']-df_rf['true']
df_rf
# Out:
#        true    predicted         diff
# 33881   844   737.522914  -106.477086
# 21091  9261  8064.172167 -1196.827833
# 36464   942   835.288710  -106.711290
# 40260   492   629.821429   137.821429
# 1632   3016  3185.439437   169.439437
# ...     ...          ...          ...
# 37688   993   884.921706  -108.078294
# 53373  2659  2585.481357   -73.518643
# 47479  1861  1800.300663   -60.699337
# 13818  5630  5761.223333   131.223333
# 10163  4729  5073.726712   344.726712
#
# [17793 rows x 3 columns]

# %%
print('Random forest regression accuracy: ')
#crossl = cross_val_score(estimator = model, X = x_train, y = y_train, cv = 4,verbose = 0)
msel = mean_squared_error(y_test, y_pred2)
rmsel = mean_squared_error(y_test, y_pred2)**0.5
mael = mean_absolute_error(y_test, y_pred2)
msle =mean_squared_log_error(y_test,y_pred2)
#print('Cross val     : ',crossl)
print('MAE           : ', mael)
print('MSE (RMSE)    : ', msel,' (',rmsel,')')
print("MSLE  :", msle)
# Out:
# Random forest regression accuracy:
# MAE           :  295.1842430347263
# MSE (RMSE)    :  330125.5037620362  ( 574.5654912732197 )
# MSLE  : 0.011970020277838278

# %%
#select model
model = rf
model
# Out:
# RandomForestRegressor(random_state=42)

# %%
#4C's of diamond
new_diamond = [0.23, 5, 2, 1]
new_diamond
# Out:
# [0.23, 5, 2, 1]

# %%
prediction = model.predict([new_diamond])[0]
print("\033[1m The market price of this new diamond is ${:.2f}".format(prediction))
# Out:
#  The market price of this new diamond is $407.04
# d:\Users\Administrator\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
#Latest Graphic User Interface (GUI) Deployment
from tkinter import *
#root = tk.Tk()
root = Tk()
root.title("My Diamond Price Prediction")
#root.title("My Project")
root.geometry("400x300")
root.minsize(200,200)
root.maxsize(600,600)
root.configure(bg="lightblue")
label1=Label(root,text="Carat",bg="light blue",foreground="black",font=("New Times Roman",12,"bold"))
label1.pack()
entry1=Entry(root,width=10,font=("New Times Roman",12),bg="gray",fg="white",borderwidth=3)
entry1.pack(pady=5)
############################################################################################################
label2=Label(root,text="Cut ['I':5,'P':4,'VG':3,'G':2,'F':1]",bg="light blue",foreground="black",font=("New Times Roman",12,"bold"))
label2.pack()
entry2=Entry(root,width=10,font=("New Times Roman",12),bg="gray",fg="white",borderwidth=3)
entry2.pack(pady=5)
############################################################################################################
label3=Label(root,text="Color ['D':1,'E':2,'F':3,'G':4,'H':5, 'I':6, 'J':7]",bg="light blue",foreground="black",font=("New Times Roman",12,"bold"))
label3.pack()
entry3=Entry(root,width=10,font=("New Times Roman",12),bg="gray",fg="white",borderwidth=3)
entry3.pack(pady=5)
############################################################################################################
label4=Label(root,text="Clarity ['SI2':1,'SI1':2,'VS1':3,'VS2':4,'VVS2':5,'VVS1':6,'I1':7,'IF':8]",bg="light blue",foreground="black",font=("New Times Roman",12,"bold"))
label4.pack()
entry4=Entry(root,width=10,font=("New Times Roman",12),bg="gray",fg="white",borderwidth=3)
entry4.pack(pady=5)
############################################################################################################
#predict sepal species by user input
price_label = Label(root,text="",bg="lightblue",foreground="black",font=("Times New Roman",15,"bold"))
price_label.pack()
model=rf
def diamond_pred():
    carat = float(entry1.get())
    cut = int(entry2.get())
    color = int(entry3.get())
    clarity = int(entry4.get())
    prediction = model.predict([[carat,cut,color,clarity]])[0]
    price_label.config(text="Predicted Diamond Price is $"+"{:.2f}".format(prediction))
    print("\033[1m The market price of this new diamond is ${:.2f}".format(prediction))
myButton=Button(text="Predict",bg="lightgreen",activebackground="blue",borderwidth=3,font=("New Times Roman", 12,"bold"),command=diamond_pred)
myButton.pack(pady=10)
root.mainloop()
# Out:
# d:\Users\Administrator\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
#  The market price of this new diamond is $8738.45
# d:\Users\Administrator\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
#  The market price of this new diamond is $5414.44
# d:\Users\Administrator\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
#  The market price of this new diamond is $7399.68
# d:\Users\Administrator\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
# ...

# %%
#Graphic User Interface (GUI) Deployment
from tkinter import *
#root = tk.Tk()
root = Tk()
root.title("My Diamond Price Prediction")
#root.title("My Project")
root.geometry("400x300")
root.minsize(200,200)
root.maxsize(600,600)
root.configure(bg="lightblue")
label1=Label(root,text="Carat",bg="light blue",foreground="black",font=("New Times Roman",12,"bold"))
label1.pack()
entry1=Entry(root,width=10,font=("New Times Roman",12),bg="gray",fg="white",borderwidth=3)
entry1.pack(pady=5)
############################################################################################################
label2=Label(root,text="Cut",bg="light blue",foreground="black",font=("New Times Roman",12,"bold"))
label2.pack()
entry2=Entry(root,width=10,font=("New Times Roman",12),bg="gray",fg="white",borderwidth=3)
entry2.pack(pady=5)
############################################################################################################
label3=Label(root,text="Color",bg="light blue",foreground="black",font=("New Times Roman",12,"bold"))
label3.pack()
entry3=Entry(root,width=10,font=("New Times Roman",12),bg="gray",fg="white",borderwidth=3)
entry3.pack(pady=5)
############################################################################################################
label4=Label(root,text="Clarity",bg="light blue",foreground="black",font=("New Times Roman",12,"bold"))
label4.pack()
entry4=Entry(root,width=10,font=("New Times Roman",12),bg="gray",fg="white",borderwidth=3)
entry4.pack(pady=5)
############################################################################################################
#predict sepal species by user input
price_label = Label(root,text="",bg="lightblue",foreground="black",font=("Times New Roman",15,"bold"))
price_label.pack()
model=rf
def diamond_pred():
    carat = float(entry1.get())
    cut = int(entry2.get())
    color = int(entry3.get())
    clarity = int(entry4.get())
    prediction = model.predict([[carat,cut,color,clarity]])[0]
    price_label.config(text="Predicted Diamond Price is $"+"{:.2f}".format(prediction))
    print("\033[1m The market price of this new diamond is ${:.2f}".format(prediction))
myButton=Button(text="Predict",bg="lightgreen",activebackground="blue",borderwidth=3,font=("New Times Roman", 12,"bold"),command=diamond_pred)
myButton.pack(pady=10)
root.mainloop()
